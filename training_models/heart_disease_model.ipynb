# %%
pip install imbalanced-learn streamlit
# Out:
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.13.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: streamlit in e:\idea\.venv\lib\site-packages (1.44.1)
# Requirement already satisfied: numpy<3,>=1.24.3 in e:\idea\.venv\lib\site-packages (from imbalanced-learn) (2.2.5)
# Requirement already satisfied: scipy<2,>=1.10.1 in e:\idea\.venv\lib\site-packages (from imbalanced-learn) (1.15.2)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in e:\idea\.venv\lib\site-packages (from imbalanced-learn) (1.6.1)
# Collecting sklearn-compat<1,>=0.1 (from imbalanced-learn)
#   Downloading sklearn_compat-0.1.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: joblib<2,>=1.1.1 in e:\idea\.venv\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in e:\idea\.venv\lib\site-packages (from imbalanced-learn) (3.6.0)
# Requirement already satisfied: altair<6,>=4.0 in e:\idea\.venv\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in e:\idea\.venv\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in e:\idea\.venv\lib\site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in e:\idea\.venv\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: packaging<25,>=20 in e:\idea\.venv\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in e:\idea\.venv\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in e:\idea\.venv\lib\site-packages (from streamlit) (11.2.1)
# Requirement already satisfied: protobuf<6,>=3.20 in e:\idea\.venv\lib\site-packages (from streamlit) (5.29.4)
# Requirement already satisfied: pyarrow>=7.0 in e:\idea\.venv\lib\site-packages (from streamlit) (20.0.0)
# Requirement already satisfied: requests<3,>=2.27 in e:\idea\.venv\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in e:\idea\.venv\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in e:\idea\.venv\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in e:\idea\.venv\lib\site-packages (from streamlit) (4.13.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in e:\idea\.venv\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in e:\idea\.venv\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in e:\idea\.venv\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in e:\idea\.venv\lib\site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in e:\idea\.venv\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in e:\idea\.venv\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in e:\idea\.venv\lib\site-packages (from altair<6,>=4.0->streamlit) (1.36.0)
# Requirement already satisfied: colorama in e:\idea\.venv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in e:\idea\.venv\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in e:\idea\.venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\idea\.venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\idea\.venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\idea\.venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\idea\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in e:\idea\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\idea\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\idea\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\idea\.venv\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in e:\idea\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in e:\idea\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in e:\idea\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in e:\idea\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.24.0)
# Requirement already satisfied: six>=1.5 in e:\idea\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
# Downloading sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Installing collected packages: sklearn-compat, imbalanced-learn
#
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    ---------------------------------------- 2/2 [imbalanced-learn]
#
# Successfully installed imbalanced-learn-0.13.0 sklearn-compat-0.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
from imblearn.under_sampling import TomekLinks

# %%
# Load Heart Disease dataset
heart_df = pd.read_csv("../datasets/heart.csv")

# %%
# Explore the dataset
print("Heart Disease Dataset:")
print(heart_df.head())
# Out:
# Heart Disease Dataset:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
print(heart_df['target'].value_counts())  # Checking imbalance
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
# Splitting Features and Target
X_heart = heart_df.drop(columns=['target'])
y_heart = heart_df['target']

# %%
# Applying Tomek Links to reduce imbalance
tomek = TomekLinks()
X_heart_resampled, y_heart_resampled = tomek.fit_resample(X_heart, y_heart)

# %%
# Splitting data into training and testing sets
X_train_heart, X_test_heart, y_train_heart, y_test_heart = train_test_split(X_heart_resampled, y_heart_resampled, test_size=0.2, random_state=44)

# %%
# Train SVM model for Heart Disease
model_heart = svm.SVC(kernel='linear')
model_heart.fit(X_train_heart, y_train_heart)
# Out:
# SVC(kernel='linear')

# %%
# Make predictions on the test set
y_pred_heart = model_heart.predict(X_test_heart)

# %%
# Evaluate the model
print("Heart Disease Prediction Metrics:")
print("Accuracy:", accuracy_score(y_test_heart, y_pred_heart))
print("Precision:", precision_score(y_test_heart, y_pred_heart))
print("Recall:", recall_score(y_test_heart, y_pred_heart))
print("Confusion Matrix:\n", confusion_matrix(y_test_heart, y_pred_heart))
# Out:
# Heart Disease Prediction Metrics:
# Accuracy: 0.8909090909090909
# Precision: 0.8857142857142857
# Recall: 0.9393939393939394
# Confusion Matrix:
#  [[18  4]
#  [ 2 31]]

# %%
# Save models
pickle.dump(model_heart, open('heart_disease_model.sav', 'wb'))
